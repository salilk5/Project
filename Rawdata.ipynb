# %% [markdown]
# <a href="https://colab.research.google.com/github/salilk5/Project/blob/main/Rawdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4a43c3ba-d19c-4040-bc73-ff34acb270b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a43c3ba-d19c-4040-bc73-ff34acb270b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_name = 'Raw_data_1Day_2020_site_119_Sirifort_Delhi_CPCB_1Day.xls'
df = pd.read_excel(file_name)
display(df.head())
print(f"DataFrame shape: {df.shape}")
df.info()
# Out:
#    Timestamp  PM2.5 (Âµg/mÂ³)  PM10 (Âµg/mÂ³)  NO (Âµg/mÂ³)  NO2 (Âµg/mÂ³)  \
# 0 2020-01-01           446.66          541.86        180.44         118.46
# 1 2020-01-02           332.49          437.43        201.16         129.59
# 2 2020-01-03           320.41          446.02        171.47         105.70
# 3 2020-01-04           203.65          316.14         93.59          79.60
# 4 2020-01-05           173.62          261.22         37.05          54.94
#
#    NOx (ppb)  NH3 (Âµg/mÂ³)  SO2 (Âµg/mÂ³)  CO (mg/mÂ³)  Ozone (Âµg/mÂ³)  ...  \
# 0     212.95          75.42          20.69         6.22            17.85  ...
# 1     228.97          79.99          21.77         6.03            19.26  ...
# 2     192.72          69.39          16.96         4.53            19.06  ...
# 3     116.75          47.03          10.36         2.94            26.49  ...
# 4      58.83          29.93           5.22         1.30            33.00  ...
#
# ...

# %%
display(df.describe())
# Out:
#                  Timestamp  PM2.5 (Âµg/mÂ³)  PM10 (Âµg/mÂ³)  NO (Âµg/mÂ³)  \
# count                  366       361.000000      362.000000    366.000000
# mean   2020-07-01 12:00:00        90.178421      181.963177     18.426311
# min    2020-01-01 00:00:00        10.560000       20.280000      1.270000
# 25%    2020-04-01 06:00:00        38.070000       94.487500      5.375000
# 50%    2020-07-01 12:00:00        64.620000      154.470000      9.055000
# 75%    2020-09-30 18:00:00       122.440000      252.822500     22.305000
# max    2020-12-31 00:00:00       469.830000      645.320000    201.160000
# std                    NaN        75.646921      110.697932     24.534453
#
#        NO2 (Âµg/mÂ³)   NOx (ppb)  NH3 (Âµg/mÂ³)  SO2 (Âµg/mÂ³)  CO (mg/mÂ³)  \
# count     366.000000  366.000000     366.000000      366.00000   366.000000
# mean       39.348525   39.653415      20.449754       12.54347     1.152077
# ...

# %% [markdown]
# Here's a breakdown of each column in your DataFrame:
#
# *   **Timestamp**: The date and time of the recorded data, indicating the daily measurements.
# *   **PM2.5 (Âµg/mÂ³)**: Particulate Matter 2.5 micrometers or less in diameter, measured in micrograms per cubic meter. These are fine inhalable particles, which can reduce visibility and cause health problems.
# *   **PM10 (Âµg/mÂ³)**: Particulate Matter 10 micrometers or less in diameter, measured in micrograms per cubic meter. These are inhalable particles, smaller than PM2.5.
# *   **NO (Âµg/mÂ³)**: Nitric Oxide, a gaseous pollutant, measured in micrograms per cubic meter.
# *   **NO2 (Âµg/mÂ³)**: Nitrogen Dioxide, another gaseous pollutant, measured in micrograms per cubic meter.
# *   **NOx (ppb)**: Nitrogen Oxides (sum of NO and NO2), measured in parts per billion.
# *   **NH3 (Âµg/mÂ³)**: Ammonia, a gaseous pollutant, measured in micrograms per cubic meter.
# *   **SO2 (Âµg/mÂ³)**: Sulfur Dioxide, a gaseous pollutant, measured in micrograms per cubic meter.
# *   **CO (mg/mÂ³)**: Carbon Monoxide, a gaseous pollutant, measured in milligrams per cubic meter.
# *   **Ozone (Âµg/mÂ³)**: Ozone (O3), a gaseous pollutant, measured in micrograms per cubic meter.
# *   **Benzene (Âµg/mÂ³)**: Benzene, a volatile organic compound (VOC), measured in micrograms per cubic meter.
# *   **Toluene (Âµg/mÂ³)**: Toluene, a VOC, measured in micrograms per cubic meter.
# *   **Xylene (Âµg/mÂ³)**: Xylene, a VOC, measured in micrograms per cubic meter. This column appears to be entirely null.
# *   **O Xylene (Âµg/mÂ³)**: Ortho-Xylene, a specific isomer of xylene, measured in micrograms per cubic meter. This column appears to be entirely null.
# *   **Eth-Benzene (Âµg/mÂ³)**: Ethylbenzene, a VOC, measured in micrograms per cubic meter.
# *   **MP-Xylene (Âµg/mÂ³)**: Meta-Para Xylene, a combination of meta and para isomers of xylene, measured in micrograms per cubic meter.
# *   **AT (Â°C)**: Ambient Temperature, measured in degrees Celsius. This column appears to be entirely null.
# *   **RH (%)**: Relative Humidity, measured in percentage.
# *   **WS (m/s)**: Wind Speed, measured in meters per second.
# *   **WD (deg)**: Wind Direction, measured in degrees.
# *   **RF (mm)**: Rainfall, measured in millimeters.
# *   **TOT-RF (mm)**: Total Rainfall, measured in millimeters.
# *   **SR (W/mt2)**: Solar Radiation, measured in Watts per square meter.
# *   **BP (mmHg)**: Barometric Pressure, measured in millimeters of mercury. This column appears to be entirely null.
# *   **VWS (m/s)**: Vertical Wind Speed, measured in meters per second. This column appears to be entirely null.

# %% [markdown]
# Once the file is uploaded, you can load it into a pandas DataFrame like this:
